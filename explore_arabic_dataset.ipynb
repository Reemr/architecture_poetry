# %%
import pandas as pd
import numpy as np
import os
import re
import json
import string
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
arb_path = '/content/drive/MyDrive/AI Artathon/Arabic Poems Dataset/gulf_poems.csv'
arb_df = pd.read_csv(arb_path)
arb_df.head(3)
# Out:
#    poem_id  ...     poet_name
# 0      173  ...  غازي القصيبي
# 1      175  ...  غازي القصيبي
# 2      176  ...  غازي القصيبي
#
# [3 rows x 9 columns]

# %%
arb_df.poet_cat.value_counts()
# Out:
# السعودية    1931
# اليمن        700
# عمان         619
# الإمارات     563
# البحرين      555
# الكويت        54
# قطر           22
# Name: poet_cat, dtype: int64

# %%
arb_df['poem_text'] = arb_df['poem_text'].astype('str')

# %%
txt = ' '.join(arb_df.poem_text)
txt
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tokens = nltk.word_tokenize(txt)

# %%
len(tokens)
# Out:
# 866920

# %%
from collections import Counter
c = Counter(uq_tokens)

print(c)
